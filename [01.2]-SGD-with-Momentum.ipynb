# %% [markdown]
# ### Adagrad - optimize learning rate

# %%
# implemented by HuyIGW04
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms as tf    # for convert tensor
from torch.utils.data import DataLoader

# %%
# setup device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
train_set = datasets.FashionMNIST(root='FashionMNIST-data',
                                  train=True,
                                  transform=tf.ToTensor(),
                                  download='True')

test_set = datasets.FashionMNIST(root='FashionMNIST-data',
                                 train=False,
                                 transform=tf.ToTensor(),
                                 download=True)

print(train_set.classes)
# Out:
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# MNIST data, ~ 1024
train_dataloader = DataLoader(train_set, 
                              batch_size=1024,
                              shuffle=True)

test_dataloader = DataLoader(test_set,
                             batch_size=1024)

train_dataloader.dataset
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: FashionMNIST-data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
# basic custom: 784:128:64:10
class customNN(nn.Module):
    def __init__(self):
        super(customNN, self).__init__()
        
        self.flatten = nn.Flatten()
        self.MLP = nn.Sequential(
            nn.Linear(784, 128),         # 28 x 28
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 10)           # 10 classes
        )
    
    def forward(self, x):
        x = self.flatten(x)
        x = self.MLP(x)
        return x

model = customNN().to(device)
print(model)
# Out:
# customNN(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (MLP): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# update: momentum
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
def training(dataloader, model, loss_fn, optimizer):
    """training field"""
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # forward
        X, y = X.to(device), y.to(device)
        y_hat = model(X)
        loss = loss_fn(y_hat, y)

        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # for debug
        if batch % 100 == 0:
            loss_print = loss.item()
            print(f'loss: {loss_print}')



def testing_and_metric(dataloader_obj, model, loss_fn):
    """calculate test loss and accuracy metric"""
    num_of_batch = len(dataloader_obj)
    num_of_pic = len(dataloader_obj.dataset)
    loss_test_sum = 0                                                            # calculate mean    
    acc_sum = 0                                                                  # calculate accuracy

    with torch.no_grad():
        for batch, (X, y) in enumerate(dataloader_obj):
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss = loss_fn(pred, y)
            loss_test_sum += loss.item()                                         # for loss value
            
            acc_sum += (y == pred.argmax(1)).type(torch.float).sum().item()      # class -> dim=1

    model.eval()
    loss_test_mean = loss_test_sum/num_of_batch
    acc_mean = acc_sum/num_of_pic
    print(f"Test Error:\n Accuracy: {100*acc_mean:>.2f}%,      Loss: {loss_test_mean:>.5f} \n")

# %%
epoch = 50
for i in range(epoch):
    print(f"Epoch {i+1}\n---------------------")
    training(train_dataloader, model, criterion, optimizer)
    testing_and_metric(test_dataloader, model, criterion)
print('Done!')
# Out:
# Epoch 1
# ---------------------
# loss: 2.2983431816101074
# Test Error:
#  Accuracy: 58.07%,      Loss: 1.35026
#
# Epoch 2
# ---------------------
# loss: 1.3319319486618042
# Test Error:
#  Accuracy: 67.15%,      Loss: 0.83088
#
# Epoch 3
# ---------------------
# loss: 0.8245623707771301
# Test Error:
#  Accuracy: 73.60%,      Loss: 0.70853
#
# Epoch 4
# ---------------------
# loss: 0.6633492112159729
# Test Error:
#  Accuracy: 77.36%,      Loss: 0.64088
#
# Epoch 5
# ---------------------
# loss: 0.5755451917648315
# Test Error:
#  Accuracy: 79.02%,      Loss: 0.59024
#
# Epoch 6
# ---------------------
# loss: 0.5956335663795471
# Test Error:
#  Accuracy: 80.44%,      Loss: 0.55684
#
# Epoch 7
# ---------------------
# loss: 0.5364068746566772
# Test Error:
#  Accuracy: 81.37%,      Loss: 0.52898
#
# Epoch 8
# ---------------------
# loss: 0.5501344203948975
# Test Error:
#  Accuracy: 81.90%,      Loss: 0.51678
#
# Epoch 9
# ---------------------
# loss: 0.4763071537017822
# Test Error:
#  Accuracy: 82.02%,      Loss: 0.50684
#
# Epoch 10
# ---------------------
# loss: 0.46117809414863586
# Test Error:
#  Accuracy: 82.64%,      Loss: 0.49591
#
# Epoch 11
# ---------------------
# loss: 0.505530834197998
# Test Error:
#  Accuracy: 82.76%,      Loss: 0.48732
#
# Epoch 12
# ---------------------
# loss: 0.4194132685661316
# Test Error:
#  Accuracy: 82.97%,      Loss: 0.48234
#
# Epoch 13
# ---------------------
# loss: 0.46836888790130615
# Test Error:
#  Accuracy: 83.08%,      Loss: 0.48031
#
# Epoch 14
# ---------------------
# loss: 0.3739783763885498
# Test Error:
#  Accuracy: 83.32%,      Loss: 0.46667
#
# Epoch 15
# ---------------------
# loss: 0.4614454209804535
# Test Error:
#  Accuracy: 83.65%,      Loss: 0.46365
#
# Epoch 16
# ---------------------
# loss: 0.40525808930397034
# Test Error:
#  Accuracy: 83.73%,      Loss: 0.46282
#
# Epoch 17
# ---------------------
# loss: 0.4449668526649475
# Test Error:
#  Accuracy: 84.03%,      Loss: 0.45389
#
# Epoch 18
# ---------------------
# loss: 0.4123755395412445
# Test Error:
#  Accuracy: 84.21%,      Loss: 0.44697
#
# Epoch 19
# ---------------------
# loss: 0.38635194301605225
# Test Error:
#  Accuracy: 84.40%,      Loss: 0.44314
#
# Epoch 20
# ---------------------
# loss: 0.4140453040599823
# Test Error:
#  Accuracy: 84.02%,      Loss: 0.44540
#
# Epoch 21
# ---------------------
# loss: 0.4105662405490875
# Test Error:
#  Accuracy: 84.60%,      Loss: 0.43490
#
# Epoch 22
# ---------------------
# loss: 0.4128389358520508
# Test Error:
#  Accuracy: 84.56%,      Loss: 0.43256
#
# Epoch 23
# ---------------------
# loss: 0.45816218852996826
# Test Error:
#  Accuracy: 84.67%,      Loss: 0.42994
#
# Epoch 24
# ---------------------
# loss: 0.3859539330005646
# Test Error:
#  Accuracy: 85.08%,      Loss: 0.42466
#
# Epoch 25
# ---------------------
# loss: 0.3645581305027008
# Test Error:
#  Accuracy: 84.61%,      Loss: 0.43411
#
# Epoch 26
# ---------------------
# loss: 0.3761509656906128
# Test Error:
#  Accuracy: 84.99%,      Loss: 0.41846
#
# Epoch 27
# ---------------------
# loss: 0.3753896653652191
# Test Error:
#  Accuracy: 85.34%,      Loss: 0.41539
#
# Epoch 28
# ---------------------
# loss: 0.34684866666793823
# Test Error:
#  Accuracy: 85.39%,      Loss: 0.41319
#
# Epoch 29
# ---------------------
# loss: 0.34969648718833923
# Test Error:
#  Accuracy: 85.39%,      Loss: 0.41176
#
# Epoch 30
# ---------------------
# loss: 0.3523041307926178
# Test Error:
#  Accuracy: 85.57%,      Loss: 0.40801
#
# Epoch 31
# ---------------------
# loss: 0.3405666947364807
# Test Error:
#  Accuracy: 85.53%,      Loss: 0.41025
#
# Epoch 32
# ---------------------
# loss: 0.40894076228141785
# Test Error:
#  Accuracy: 85.79%,      Loss: 0.40202
#
# Epoch 33
# ---------------------
# loss: 0.4077732264995575
# Test Error:
#  Accuracy: 85.52%,      Loss: 0.41251
#
# Epoch 34
# ---------------------
# loss: 0.3626978099346161
# Test Error:
#  Accuracy: 85.66%,      Loss: 0.40298
#
# Epoch 35
# ---------------------
# loss: 0.3458194434642792
# Test Error:
#  Accuracy: 86.02%,      Loss: 0.39652
#
# Epoch 36
# ---------------------
# loss: 0.32866090536117554
# Test Error:
#  Accuracy: 85.43%,      Loss: 0.40557
#
# Epoch 37
# ---------------------
# loss: 0.3386109173297882
# Test Error:
#  Accuracy: 85.91%,      Loss: 0.39432
#
# Epoch 38
# ---------------------
# loss: 0.3319281041622162
# Test Error:
#  Accuracy: 85.25%,      Loss: 0.40883
#
# Epoch 39
# ---------------------
# loss: 0.34567442536354065
# Test Error:
#  Accuracy: 85.98%,      Loss: 0.40087
#
# Epoch 40
# ---------------------
# loss: 0.3441380560398102
# Test Error:
#  Accuracy: 86.23%,      Loss: 0.39011
#
# Epoch 41
# ---------------------
# loss: 0.36045897006988525
# Test Error:
#  Accuracy: 86.39%,      Loss: 0.38692
#
# Epoch 42
# ---------------------
# loss: 0.34902718663215637
# Test Error:
#  Accuracy: 86.25%,      Loss: 0.39318
#
# Epoch 43
# ---------------------
# loss: 0.3715169131755829
# Test Error:
#  Accuracy: 86.51%,      Loss: 0.38196
#
# Epoch 44
# ---------------------
# loss: 0.29174187779426575
# Test Error:
#  Accuracy: 86.52%,      Loss: 0.38172
#
# Epoch 45
# ---------------------
# loss: 0.29709067940711975
# Test Error:
#  Accuracy: 86.34%,      Loss: 0.38650
#
# Epoch 46
# ---------------------
# loss: 0.3338486850261688
# Test Error:
#  Accuracy: 86.13%,      Loss: 0.38710
#
# Epoch 47
# ---------------------
# loss: 0.32372304797172546
# Test Error:
#  Accuracy: 86.78%,      Loss: 0.37865
#
# Epoch 48
# ---------------------
# loss: 0.33543163537979126
# Test Error:
#  Accuracy: 86.27%,      Loss: 0.38440
#
# Epoch 49
# ---------------------
# loss: 0.33702921867370605
# Test Error:
#  Accuracy: 86.72%,      Loss: 0.37578
#
# Epoch 50
# ---------------------
# loss: 0.2900102734565735
# Test Error:
#  Accuracy: 86.72%,      Loss: 0.37493
#
# Done!
