# %% [markdown]
# ### Adagrad - optimize learning rate

# %%
# implemented by HuyIGW04
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms as tf    # for convert tensor
from torch.utils.data import DataLoader

# %%
# setup device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
train_set = datasets.FashionMNIST(root='FashionMNIST-data',
                                  train=True,
                                  transform=tf.ToTensor(),
                                  download='True')

test_set = datasets.FashionMNIST(root='FashionMNIST-data',
                                 train=False,
                                 transform=tf.ToTensor(),
                                 download=True)

print(train_set.classes)
# Out:
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# MNIST data, ~ 1024
train_dataloader = DataLoader(train_set, 
                              batch_size=1024,
                              shuffle=True)

test_dataloader = DataLoader(test_set,
                             batch_size=1024)

train_dataloader.dataset
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: FashionMNIST-data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
# basic custom: 784:128:64:10
class customNN(nn.Module):
    def __init__(self):
        super(customNN, self).__init__()
        
        self.flatten = nn.Flatten()
        self.MLP = nn.Sequential(
            nn.Linear(784, 128),         # 28 x 28
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 10)           # 10 classes
        )
    
    def forward(self, x):
        x = self.flatten(x)
        x = self.MLP(x)
        return x

model = customNN().to(device)
print(model)
# Out:
# customNN(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (MLP): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adagrad(model.parameters(), lr=0.01)

# %%
def training(dataloader, model, loss_fn, optimizer):
    """training field"""
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # forward
        X, y = X.to(device), y.to(device)
        y_hat = model(X)
        loss = loss_fn(y_hat, y)

        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # for debug
        if batch % 100 == 0:
            loss_print = loss.item()
            print(f'loss: {loss_print}')



def testing_and_metric(dataloader_obj, model, loss_fn):
    """calculate test loss and accuracy metric"""
    num_of_batch = len(dataloader_obj)
    num_of_pic = len(dataloader_obj.dataset)
    loss_test_sum = 0                                                            # calculate mean    
    acc_sum = 0                                                                  # calculate accuracy

    with torch.no_grad():
        for batch, (X, y) in enumerate(dataloader_obj):
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss = loss_fn(pred, y)
            loss_test_sum += loss.item()                                         # for loss value
            
            acc_sum += (y == pred.argmax(1)).type(torch.float).sum().item()      # class -> dim=1

    model.eval()
    loss_test_mean = loss_test_sum/num_of_batch
    acc_mean = acc_sum/num_of_pic
    print(f"Test Error:\n Accuracy: {100*acc_mean:>.2f}%,      Loss: {loss_test_mean:>.5f} \n")

# %%
epoch = 50
for i in range(epoch):
    print(f"Epoch {i+1}\n---------------------")
    training(train_dataloader, model, criterion, optimizer)
    testing_and_metric(test_dataloader, model, criterion)
print('Done!')
# Out:
# Epoch 1
# ---------------------
# loss: 2.3106534481048584
# Test Error:
#  Accuracy: 75.98%,      Loss: 0.66460
#
# Epoch 2
# ---------------------
# loss: 0.6529419422149658
# Test Error:
#  Accuracy: 80.06%,      Loss: 0.55039
#
# Epoch 3
# ---------------------
# loss: 0.5005916953086853
# Test Error:
#  Accuracy: 82.14%,      Loss: 0.49982
#
# Epoch 4
# ---------------------
# loss: 0.4495792090892792
# Test Error:
#  Accuracy: 82.56%,      Loss: 0.48630
#
# Epoch 5
# ---------------------
# loss: 0.4895348846912384
# Test Error:
#  Accuracy: 83.18%,      Loss: 0.46989
#
# Epoch 6
# ---------------------
# loss: 0.4446101188659668
# Test Error:
#  Accuracy: 84.10%,      Loss: 0.44864
#
# Epoch 7
# ---------------------
# loss: 0.38522863388061523
# Test Error:
#  Accuracy: 84.16%,      Loss: 0.44168
#
# Epoch 8
# ---------------------
# loss: 0.41414347290992737
# Test Error:
#  Accuracy: 84.18%,      Loss: 0.44348
#
# Epoch 9
# ---------------------
# loss: 0.4401167035102844
# Test Error:
#  Accuracy: 84.33%,      Loss: 0.43086
#
# Epoch 10
# ---------------------
# loss: 0.436571329832077
# Test Error:
#  Accuracy: 84.90%,      Loss: 0.41857
#
# Epoch 11
# ---------------------
# loss: 0.39530113339424133
# Test Error:
#  Accuracy: 85.35%,      Loss: 0.40974
#
# Epoch 12
# ---------------------
# loss: 0.3606836795806885
# Test Error:
#  Accuracy: 85.43%,      Loss: 0.40343
#
# Epoch 13
# ---------------------
# loss: 0.337077260017395
# Test Error:
#  Accuracy: 86.14%,      Loss: 0.39655
#
# Epoch 14
# ---------------------
# loss: 0.36540165543556213
# Test Error:
#  Accuracy: 85.93%,      Loss: 0.39358
#
# Epoch 15
# ---------------------
# loss: 0.3653295040130615
# Test Error:
#  Accuracy: 85.97%,      Loss: 0.39283
#
# Epoch 16
# ---------------------
# loss: 0.32643476128578186
# Test Error:
#  Accuracy: 86.29%,      Loss: 0.38534
#
# Epoch 17
# ---------------------
# loss: 0.3524906039237976
# Test Error:
#  Accuracy: 86.34%,      Loss: 0.38405
#
# Epoch 18
# ---------------------
# loss: 0.34060901403427124
# Test Error:
#  Accuracy: 86.32%,      Loss: 0.37699
#
# Epoch 19
# ---------------------
# loss: 0.33790135383605957
# Test Error:
#  Accuracy: 86.32%,      Loss: 0.37979
#
# Epoch 20
# ---------------------
# loss: 0.37371379137039185
# Test Error:
#  Accuracy: 86.35%,      Loss: 0.37701
#
# Epoch 21
# ---------------------
# loss: 0.3134831488132477
# Test Error:
#  Accuracy: 86.44%,      Loss: 0.37815
#
# Epoch 22
# ---------------------
# loss: 0.34150898456573486
# Test Error:
#  Accuracy: 86.61%,      Loss: 0.37018
#
# Epoch 23
# ---------------------
# loss: 0.3301858603954315
# Test Error:
#  Accuracy: 86.34%,      Loss: 0.38251
#
# Epoch 24
# ---------------------
# loss: 0.3051649034023285
# Test Error:
#  Accuracy: 86.98%,      Loss: 0.36443
#
# Epoch 25
# ---------------------
# loss: 0.31946489214897156
# Test Error:
#  Accuracy: 86.26%,      Loss: 0.37344
#
# Epoch 26
# ---------------------
# loss: 0.31696686148643494
# Test Error:
#  Accuracy: 87.02%,      Loss: 0.36336
#
# Epoch 27
# ---------------------
# loss: 0.3065185844898224
# Test Error:
#  Accuracy: 87.09%,      Loss: 0.35925
#
# Epoch 28
# ---------------------
# loss: 0.30491483211517334
# Test Error:
#  Accuracy: 87.13%,      Loss: 0.35772
#
# Epoch 29
# ---------------------
# loss: 0.32597780227661133
# Test Error:
#  Accuracy: 86.69%,      Loss: 0.36438
#
# Epoch 30
# ---------------------
# loss: 0.3227269947528839
# Test Error:
#  Accuracy: 87.21%,      Loss: 0.35643
#
# Epoch 31
# ---------------------
# loss: 0.31455400586128235
# Test Error:
#  Accuracy: 87.30%,      Loss: 0.35655
#
# Epoch 32
# ---------------------
# loss: 0.2645935118198395
# Test Error:
#  Accuracy: 87.00%,      Loss: 0.36379
#
# Epoch 33
# ---------------------
# loss: 0.2847282588481903
# Test Error:
#  Accuracy: 87.31%,      Loss: 0.35279
#
# Epoch 34
# ---------------------
# loss: 0.25884875655174255
# Test Error:
#  Accuracy: 87.31%,      Loss: 0.35361
#
# Epoch 35
# ---------------------
# loss: 0.29222387075424194
# Test Error:
#  Accuracy: 87.36%,      Loss: 0.35239
#
# Epoch 36
# ---------------------
# loss: 0.27322250604629517
# Test Error:
#  Accuracy: 86.59%,      Loss: 0.36302
#
# Epoch 37
# ---------------------
# loss: 0.27705252170562744
# Test Error:
#  Accuracy: 87.67%,      Loss: 0.34899
#
# Epoch 38
# ---------------------
# loss: 0.27982646226882935
# Test Error:
#  Accuracy: 87.45%,      Loss: 0.35793
#
# Epoch 39
# ---------------------
# loss: 0.31047800183296204
# Test Error:
#  Accuracy: 87.57%,      Loss: 0.34740
#
# Epoch 40
# ---------------------
# loss: 0.31964051723480225
# Test Error:
#  Accuracy: 86.50%,      Loss: 0.36501
#
# Epoch 41
# ---------------------
# loss: 0.30814263224601746
# Test Error:
#  Accuracy: 87.66%,      Loss: 0.34332
#
# Epoch 42
# ---------------------
# loss: 0.27421441674232483
# Test Error:
#  Accuracy: 87.19%,      Loss: 0.35135
#
# Epoch 43
# ---------------------
# loss: 0.25838854908943176
# Test Error:
#  Accuracy: 87.69%,      Loss: 0.34798
#
# Epoch 44
# ---------------------
# loss: 0.2806468904018402
# Test Error:
#  Accuracy: 87.81%,      Loss: 0.34226
#
# Epoch 45
# ---------------------
# loss: 0.2473645657300949
# Test Error:
#  Accuracy: 87.92%,      Loss: 0.34322
#
# Epoch 46
# ---------------------
# loss: 0.3005794286727905
# Test Error:
#  Accuracy: 87.99%,      Loss: 0.34209
#
# Epoch 47
# ---------------------
# loss: 0.2757655382156372
# Test Error:
#  Accuracy: 87.78%,      Loss: 0.34077
#
# Epoch 48
# ---------------------
# loss: 0.2599683105945587
# Test Error:
#  Accuracy: 87.74%,      Loss: 0.34576
#
# Epoch 49
# ---------------------
# loss: 0.23113664984703064
# Test Error:
#  Accuracy: 88.01%,      Loss: 0.34162
#
# Epoch 50
# ---------------------
# loss: 0.28848761320114136
# Test Error:
#  Accuracy: 87.92%,      Loss: 0.34216
#
# Done!
