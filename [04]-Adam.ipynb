# %% [markdown]
# ### Adagrad - optimize learning rate

# %%
# implemented by HuyIGW04
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms as tf    # for convert tensor
from torch.utils.data import DataLoader

# %%
# setup device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
train_set = datasets.FashionMNIST(root='FashionMNIST-data',
                                  train=True,
                                  transform=tf.ToTensor(),
                                  download='True')

test_set = datasets.FashionMNIST(root='FashionMNIST-data',
                                 train=False,
                                 transform=tf.ToTensor(),
                                 download=True)

print(train_set.classes)
# Out:
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# MNIST data, ~ 1024
train_dataloader = DataLoader(train_set, 
                              batch_size=1024,
                              shuffle=True)

test_dataloader = DataLoader(test_set,
                             batch_size=1024)

train_dataloader.dataset
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: FashionMNIST-data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
# basic custom: 784:128:64:10
class customNN(nn.Module):
    def __init__(self):
        super(customNN, self).__init__()
        
        self.flatten = nn.Flatten()
        self.MLP = nn.Sequential(
            nn.Linear(784, 128),         # 28 x 28
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 10)           # 10 classes
        )
    
    def forward(self, x):
        x = self.flatten(x)
        x = self.MLP(x)
        return x

model = customNN().to(device)
print(model)
# Out:
# customNN(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (MLP): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
def training(dataloader, model, loss_fn, optimizer):
    """training field"""
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # forward
        X, y = X.to(device), y.to(device)
        y_hat = model(X)
        loss = loss_fn(y_hat, y)

        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # for debug
        if batch % 100 == 0:
            loss_print = loss.item()
            print(f'loss: {loss_print}')



def testing_and_metric(dataloader_obj, model, loss_fn):
    """calculate test loss and accuracy metric"""
    num_of_batch = len(dataloader_obj)
    num_of_pic = len(dataloader_obj.dataset)
    loss_test_sum = 0                                                            # calculate mean    
    acc_sum = 0                                                                  # calculate accuracy

    with torch.no_grad():
        for batch, (X, y) in enumerate(dataloader_obj):
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss = loss_fn(pred, y)
            loss_test_sum += loss.item()                                         # for loss value
            
            acc_sum += (y == pred.argmax(1)).type(torch.float).sum().item()      # class -> dim=1

    model.eval()
    loss_test_mean = loss_test_sum/num_of_batch
    acc_mean = acc_sum/num_of_pic
    print(f"Test Error:\n Accuracy: {100*acc_mean:>.2f}%,      Loss: {loss_test_mean:>.5f} \n")

# %%
epoch = 50
for i in range(epoch):
    print(f"Epoch {i+1}\n---------------------")
    training(train_dataloader, model, criterion, optimizer)
    testing_and_metric(test_dataloader, model, criterion)
print('Done!')
# Out:
# Epoch 1
# ---------------------
# loss: 2.3025732040405273
# Test Error:
#  Accuracy: 81.91%,      Loss: 0.50436
#
# Epoch 2
# ---------------------
# loss: 0.46342411637306213
# Test Error:
#  Accuracy: 84.27%,      Loss: 0.43188
#
# Epoch 3
# ---------------------
# loss: 0.42623960971832275
# Test Error:
#  Accuracy: 85.50%,      Loss: 0.39137
#
# Epoch 4
# ---------------------
# loss: 0.35954028367996216
# Test Error:
#  Accuracy: 86.80%,      Loss: 0.36937
#
# Epoch 5
# ---------------------
# loss: 0.28973257541656494
# Test Error:
#  Accuracy: 87.21%,      Loss: 0.35746
#
# Epoch 6
# ---------------------
# loss: 0.26318320631980896
# Test Error:
#  Accuracy: 87.53%,      Loss: 0.34549
#
# Epoch 7
# ---------------------
# loss: 0.29000967741012573
# Test Error:
#  Accuracy: 87.43%,      Loss: 0.35220
#
# Epoch 8
# ---------------------
# loss: 0.2814335525035858
# Test Error:
#  Accuracy: 87.11%,      Loss: 0.35869
#
# Epoch 9
# ---------------------
# loss: 0.2406289279460907
# Test Error:
#  Accuracy: 87.37%,      Loss: 0.35453
#
# Epoch 10
# ---------------------
# loss: 0.28692689538002014
# Test Error:
#  Accuracy: 87.92%,      Loss: 0.36452
#
# Epoch 11
# ---------------------
# loss: 0.2632148861885071
# Test Error:
#  Accuracy: 87.02%,      Loss: 0.36185
#
# Epoch 12
# ---------------------
# loss: 0.2870701849460602
# Test Error:
#  Accuracy: 87.89%,      Loss: 0.34203
#
# Epoch 13
# ---------------------
# loss: 0.24109607934951782
# Test Error:
#  Accuracy: 87.46%,      Loss: 0.35031
#
# Epoch 14
# ---------------------
# loss: 0.26342204213142395
# Test Error:
#  Accuracy: 87.99%,      Loss: 0.35404
#
# Epoch 15
# ---------------------
# loss: 0.20800967514514923
# Test Error:
#  Accuracy: 87.68%,      Loss: 0.36409
#
# Epoch 16
# ---------------------
# loss: 0.24481403827667236
# Test Error:
#  Accuracy: 88.40%,      Loss: 0.34773
#
# Epoch 17
# ---------------------
# loss: 0.225698322057724
# Test Error:
#  Accuracy: 87.81%,      Loss: 0.34285
#
# Epoch 18
# ---------------------
# loss: 0.1994631290435791
# Test Error:
#  Accuracy: 87.55%,      Loss: 0.36400
#
# Epoch 19
# ---------------------
# loss: 0.23914209008216858
# Test Error:
#  Accuracy: 88.92%,      Loss: 0.34111
#
# Epoch 20
# ---------------------
# loss: 0.17211009562015533
# Test Error:
#  Accuracy: 87.13%,      Loss: 0.40001
#
# Epoch 21
# ---------------------
# loss: 0.21952871978282928
# Test Error:
#  Accuracy: 88.31%,      Loss: 0.34577
#
# Epoch 22
# ---------------------
# loss: 0.192659392952919
# Test Error:
#  Accuracy: 88.70%,      Loss: 0.35510
#
# Epoch 23
# ---------------------
# loss: 0.1928727626800537
# Test Error:
#  Accuracy: 88.76%,      Loss: 0.33794
#
# Epoch 24
# ---------------------
# loss: 0.18078088760375977
# Test Error:
#  Accuracy: 88.97%,      Loss: 0.34264
#
# Epoch 25
# ---------------------
# loss: 0.15889155864715576
# Test Error:
#  Accuracy: 88.36%,      Loss: 0.36288
#
# Epoch 26
# ---------------------
# loss: 0.1891137659549713
# Test Error:
#  Accuracy: 88.52%,      Loss: 0.35432
#
# Epoch 27
# ---------------------
# loss: 0.21159547567367554
# Test Error:
#  Accuracy: 88.25%,      Loss: 0.37587
#
# Epoch 28
# ---------------------
# loss: 0.1562482714653015
# Test Error:
#  Accuracy: 88.62%,      Loss: 0.36430
#
# Epoch 29
# ---------------------
# loss: 0.17702001333236694
# Test Error:
#  Accuracy: 88.38%,      Loss: 0.37877
#
# Epoch 30
# ---------------------
# loss: 0.17593474686145782
# Test Error:
#  Accuracy: 87.91%,      Loss: 0.38241
#
# Epoch 31
# ---------------------
# loss: 0.20570437610149384
# Test Error:
#  Accuracy: 88.38%,      Loss: 0.39049
#
# Epoch 32
# ---------------------
# loss: 0.16107921302318573
# Test Error:
#  Accuracy: 88.62%,      Loss: 0.40466
#
# Epoch 33
# ---------------------
# loss: 0.15983609855175018
# Test Error:
#  Accuracy: 88.76%,      Loss: 0.38249
#
# Epoch 34
# ---------------------
# loss: 0.15791164338588715
# Test Error:
#  Accuracy: 88.60%,      Loss: 0.39403
#
# Epoch 35
# ---------------------
# loss: 0.18125037848949432
# Test Error:
#  Accuracy: 88.42%,      Loss: 0.39855
#
# Epoch 36
# ---------------------
# loss: 0.1398053765296936
# Test Error:
#  Accuracy: 88.61%,      Loss: 0.40279
#
# Epoch 37
# ---------------------
# loss: 0.14720270037651062
# Test Error:
#  Accuracy: 88.64%,      Loss: 0.38801
#
# Epoch 38
# ---------------------
# loss: 0.13787409663200378
# Test Error:
#  Accuracy: 87.82%,      Loss: 0.42693
#
# Epoch 39
# ---------------------
# loss: 0.17470933496952057
# Test Error:
#  Accuracy: 88.77%,      Loss: 0.40261
#
# Epoch 40
# ---------------------
# loss: 0.14747893810272217
# Test Error:
#  Accuracy: 88.87%,      Loss: 0.41324
#
# Epoch 41
# ---------------------
# loss: 0.13882535696029663
# Test Error:
#  Accuracy: 87.88%,      Loss: 0.44654
#
# Epoch 42
# ---------------------
# loss: 0.15367324650287628
# Test Error:
#  Accuracy: 87.77%,      Loss: 0.43843
#
# Epoch 43
# ---------------------
# loss: 0.18367041647434235
# Test Error:
#  Accuracy: 89.04%,      Loss: 0.41707
#
# Epoch 44
# ---------------------
# loss: 0.13940095901489258
# Test Error:
#  Accuracy: 88.29%,      Loss: 0.44975
#
# Epoch 45
# ---------------------
# loss: 0.13496440649032593
# Test Error:
#  Accuracy: 88.64%,      Loss: 0.43246
#
# Epoch 46
# ---------------------
# loss: 0.11785470694303513
# Test Error:
#  Accuracy: 88.52%,      Loss: 0.44408
#
# Epoch 47
# ---------------------
# loss: 0.14201916754245758
# Test Error:
#  Accuracy: 88.26%,      Loss: 0.48056
#
# Epoch 48
# ---------------------
# loss: 0.1357468068599701
# Test Error:
#  Accuracy: 88.31%,      Loss: 0.45897
#
# Epoch 49
# ---------------------
# loss: 0.16016975045204163
# Test Error:
#  Accuracy: 88.37%,      Loss: 0.44131
#
# Epoch 50
# ---------------------
# loss: 0.11566852778196335
# Test Error:
#  Accuracy: 88.61%,      Loss: 0.46161
#
# Done!
