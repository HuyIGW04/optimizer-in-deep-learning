# %% [markdown]
# ### Adagrad - optimize learning rate

# %%
# implemented by HuyIGW04
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms as tf    # for convert tensor
from torch.utils.data import DataLoader

# %%
# setup device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
train_set = datasets.FashionMNIST(root='FashionMNIST-data',
                                  train=True,
                                  transform=tf.ToTensor(),
                                  download='True')

test_set = datasets.FashionMNIST(root='FashionMNIST-data',
                                 train=False,
                                 transform=tf.ToTensor(),
                                 download=True)

print(train_set.classes)
# Out:
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# MNIST data, ~ 1024
train_dataloader = DataLoader(train_set, 
                              batch_size=1024,
                              shuffle=True)

test_dataloader = DataLoader(test_set,
                             batch_size=1024)

train_dataloader.dataset
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: FashionMNIST-data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
# basic custom: 784:128:64:10
class customNN(nn.Module):
    def __init__(self):
        super(customNN, self).__init__()
        
        self.flatten = nn.Flatten()
        self.MLP = nn.Sequential(
            nn.Linear(784, 128),         # 28 x 28
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 10)           # 10 classes
        )
    
    def forward(self, x):
        x = self.flatten(x)
        x = self.MLP(x)
        return x

model = customNN().to(device)
print(model)
# Out:
# customNN(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (MLP): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=0.01)

# %%
def training(dataloader, model, loss_fn, optimizer):
    """training field"""
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # forward
        X, y = X.to(device), y.to(device)
        y_hat = model(X)
        loss = loss_fn(y_hat, y)

        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # for debug
        if batch % 100 == 0:
            loss_print = loss.item()
            print(f'loss: {loss_print}')



def testing_and_metric(dataloader_obj, model, loss_fn):
    """calculate test loss and accuracy metric"""
    num_of_batch = len(dataloader_obj)
    num_of_pic = len(dataloader_obj.dataset)
    loss_test_sum = 0                                                            # calculate mean    
    acc_sum = 0                                                                  # calculate accuracy

    with torch.no_grad():
        for batch, (X, y) in enumerate(dataloader_obj):
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss = loss_fn(pred, y)
            loss_test_sum += loss.item()                                         # for loss value
            
            acc_sum += (y == pred.argmax(1)).type(torch.float).sum().item()      # class -> dim=1

    model.eval()
    loss_test_mean = loss_test_sum/num_of_batch
    acc_mean = acc_sum/num_of_pic
    print(f"Test Error:\n Accuracy: {100*acc_mean:>.2f}%,      Loss: {loss_test_mean:>.5f} \n")

# %%
epoch = 50
for i in range(epoch):
    print(f"Epoch {i+1}\n---------------------")
    training(train_dataloader, model, criterion, optimizer)
    testing_and_metric(test_dataloader, model, criterion)
print('Done!')
# Out:
# Epoch 1
# ---------------------
# loss: 2.3099136352539062
# Test Error:
#  Accuracy: 82.13%,      Loss: 0.48980
#
# Epoch 2
# ---------------------
# loss: 0.4239487946033478
# Test Error:
#  Accuracy: 85.42%,      Loss: 0.40760
#
# Epoch 3
# ---------------------
# loss: 0.37318432331085205
# Test Error:
#  Accuracy: 85.53%,      Loss: 0.39540
#
# Epoch 4
# ---------------------
# loss: 0.36795157194137573
# Test Error:
#  Accuracy: 86.92%,      Loss: 0.36381
#
# Epoch 5
# ---------------------
# loss: 0.3418102562427521
# Test Error:
#  Accuracy: 86.60%,      Loss: 0.36825
#
# Epoch 6
# ---------------------
# loss: 0.3189794421195984
# Test Error:
#  Accuracy: 87.51%,      Loss: 0.35949
#
# Epoch 7
# ---------------------
# loss: 0.3009699285030365
# Test Error:
#  Accuracy: 87.37%,      Loss: 0.35326
#
# Epoch 8
# ---------------------
# loss: 0.29705384373664856
# Test Error:
#  Accuracy: 87.21%,      Loss: 0.35918
#
# Epoch 9
# ---------------------
# loss: 0.2679474651813507
# Test Error:
#  Accuracy: 87.65%,      Loss: 0.34694
#
# Epoch 10
# ---------------------
# loss: 0.2657059133052826
# Test Error:
#  Accuracy: 87.61%,      Loss: 0.35900
#
# Epoch 11
# ---------------------
# loss: 0.25717446208000183
# Test Error:
#  Accuracy: 87.66%,      Loss: 0.34993
#
# Epoch 12
# ---------------------
# loss: 0.31615185737609863
# Test Error:
#  Accuracy: 88.05%,      Loss: 0.33441
#
# Epoch 13
# ---------------------
# loss: 0.2223414033651352
# Test Error:
#  Accuracy: 87.51%,      Loss: 0.35040
#
# Epoch 14
# ---------------------
# loss: 0.2265716940164566
# Test Error:
#  Accuracy: 87.85%,      Loss: 0.34172
#
# Epoch 15
# ---------------------
# loss: 0.26247355341911316
# Test Error:
#  Accuracy: 87.94%,      Loss: 0.35178
#
# Epoch 16
# ---------------------
# loss: 0.217023104429245
# Test Error:
#  Accuracy: 88.35%,      Loss: 0.34355
#
# Epoch 17
# ---------------------
# loss: 0.20716679096221924
# Test Error:
#  Accuracy: 88.27%,      Loss: 0.33244
#
# Epoch 18
# ---------------------
# loss: 0.23484821617603302
# Test Error:
#  Accuracy: 87.49%,      Loss: 0.35220
#
# Epoch 19
# ---------------------
# loss: 0.2018628716468811
# Test Error:
#  Accuracy: 87.80%,      Loss: 0.37077
#
# Epoch 20
# ---------------------
# loss: 0.25107812881469727
# Test Error:
#  Accuracy: 88.49%,      Loss: 0.35626
#
# Epoch 21
# ---------------------
# loss: 0.21338512003421783
# Test Error:
#  Accuracy: 88.27%,      Loss: 0.34502
#
# Epoch 22
# ---------------------
# loss: 0.19130712747573853
# Test Error:
#  Accuracy: 88.63%,      Loss: 0.34546
#
# Epoch 23
# ---------------------
# loss: 0.18139535188674927
# Test Error:
#  Accuracy: 88.33%,      Loss: 0.35517
#
# Epoch 24
# ---------------------
# loss: 0.195665180683136
# Test Error:
#  Accuracy: 88.84%,      Loss: 0.34344
#
# Epoch 25
# ---------------------
# loss: 0.19186224043369293
# Test Error:
#  Accuracy: 88.16%,      Loss: 0.36353
#
# Epoch 26
# ---------------------
# loss: 0.20306983590126038
# Test Error:
#  Accuracy: 88.67%,      Loss: 0.34943
#
# Epoch 27
# ---------------------
# loss: 0.17634055018424988
# Test Error:
#  Accuracy: 88.51%,      Loss: 0.35588
#
# Epoch 28
# ---------------------
# loss: 0.17126187682151794
# Test Error:
#  Accuracy: 88.40%,      Loss: 0.38304
#
# Epoch 29
# ---------------------
# loss: 0.1875525712966919
# Test Error:
#  Accuracy: 88.48%,      Loss: 0.37083
#
# Epoch 30
# ---------------------
# loss: 0.1753551959991455
# Test Error:
#  Accuracy: 87.80%,      Loss: 0.39726
#
# Epoch 31
# ---------------------
# loss: 0.17438721656799316
# Test Error:
#  Accuracy: 88.59%,      Loss: 0.36656
#
# Epoch 32
# ---------------------
# loss: 0.1494428962469101
# Test Error:
#  Accuracy: 88.31%,      Loss: 0.39889
#
# Epoch 33
# ---------------------
# loss: 0.17168982326984406
# Test Error:
#  Accuracy: 88.51%,      Loss: 0.38001
#
# Epoch 34
# ---------------------
# loss: 0.16460847854614258
# Test Error:
#  Accuracy: 88.14%,      Loss: 0.38545
#
# Epoch 35
# ---------------------
# loss: 0.1618410348892212
# Test Error:
#  Accuracy: 88.69%,      Loss: 0.39095
#
# Epoch 36
# ---------------------
# loss: 0.16508056223392487
# Test Error:
#  Accuracy: 88.44%,      Loss: 0.39556
#
# Epoch 37
# ---------------------
# loss: 0.1687624752521515
# Test Error:
#  Accuracy: 88.57%,      Loss: 0.38595
#
# Epoch 38
# ---------------------
# loss: 0.1453617513179779
# Test Error:
#  Accuracy: 88.63%,      Loss: 0.39362
#
# Epoch 39
# ---------------------
# loss: 0.1428847461938858
# Test Error:
#  Accuracy: 88.69%,      Loss: 0.39815
#
# Epoch 40
# ---------------------
# loss: 0.12155239284038544
# Test Error:
#  Accuracy: 88.24%,      Loss: 0.41902
#
# Epoch 41
# ---------------------
# loss: 0.13266289234161377
# Test Error:
#  Accuracy: 88.31%,      Loss: 0.38468
#
# Epoch 42
# ---------------------
# loss: 0.1560019701719284
# Test Error:
#  Accuracy: 88.58%,      Loss: 0.41047
#
# Epoch 43
# ---------------------
# loss: 0.1189860999584198
# Test Error:
#  Accuracy: 88.71%,      Loss: 0.42666
#
# Epoch 44
# ---------------------
# loss: 0.1233772411942482
# Test Error:
#  Accuracy: 88.66%,      Loss: 0.39673
#
# Epoch 45
# ---------------------
# loss: 0.13920392096042633
# Test Error:
#  Accuracy: 88.49%,      Loss: 0.40407
#
# Epoch 46
# ---------------------
# loss: 0.1388562023639679
# Test Error:
#  Accuracy: 88.39%,      Loss: 0.40665
#
# Epoch 47
# ---------------------
# loss: 0.13641893863677979
# Test Error:
#  Accuracy: 88.51%,      Loss: 0.45724
#
# Epoch 48
# ---------------------
# loss: 0.12076607346534729
# Test Error:
#  Accuracy: 88.49%,      Loss: 0.45144
#
# Epoch 49
# ---------------------
# loss: 0.12150309234857559
# Test Error:
#  Accuracy: 88.57%,      Loss: 0.45362
#
# Epoch 50
# ---------------------
# loss: 0.1376657485961914
# Test Error:
#  Accuracy: 88.67%,      Loss: 0.43508
#
# Done!
